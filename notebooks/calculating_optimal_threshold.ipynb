# %%
from notebook_utils import plot_precision_recall_graphs

# %%
plot_precision_recall_graphs("Ethiopia_Tigray_2021_w_forecaster")
# Out:
# Caching files: 100%|██████████| 722/722 [00:00<00:00, 4228.13it/s]
# 0it [00:00, ?it/s]
# torch.Size([722, 6, 12])
# torch.Size([722, 6, 12])
# torch.Size([722, 6, 12])
# torch.Size([722, 12, 12])
# Threshold: 0.25, F1: 0.63
# (25, 0.63)
