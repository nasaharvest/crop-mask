# %%
from notebook_utils import plot_precision_recall_graphs

# %%
plot_precision_recall_graphs("Ethiopia_Tigray_2021_no_forecaster", False)
# Out:
# Caching files: 100%|██████████| 722/722 [00:00<00:00, 5043.16it/s]
# 0it [00:00, ?it/s]
# Threshold: 22, F1: 0.634
# (22, 0.634)
