# %%
from notebook_utils import plot_precision_recall_graphs

# %%
plot_precision_recall_graphs("Ethiopia_Tigray_2021_no_forecaster")
# Out:
# Caching files: 100%|██████████| 722/722 [00:00<00:00, 4229.87it/s]
# 0it [00:00, ?it/s]
# Threshold: 0.19, F1: 0.568
# (19, 0.568)
