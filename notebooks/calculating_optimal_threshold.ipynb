# %%
from notebook_utils import plot_precision_recall_graphs

# %%
plot_precision_recall_graphs("Rwanda", False)
# Out:
# Caching files: 100%|██████████| 341/341 [00:00<00:00, 3234.74it/s]
# 0it [00:00, ?it/s]
# Threshold: 48, F1: 0.726
# (48, 0.726)
